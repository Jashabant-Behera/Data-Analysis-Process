# %% [markdown]
# ## Database

# %% [markdown]
# ### What is Database?
#
# A Database is a shared collection of logically related data and description of these data, designed to meet the information need of an organization.
#
# * `Data Storage`: A database is used to store large amount of structures data, makeing it easily accessible, searchable and retrievable.
#
# * `Data Analysis`: A Database can be used to perform complex data analysis, generate reports, and provide insigts into the data.
#
# * `Record Keeping`: A Databse is often used to keep track of important records, such as financial transitions, customer infrmation, and inventory levels.
#
# * `Web Application`: Database are essential component of many web applicatins providing dynamic content and user management.

# %% [markdown]
# ### CRUD : Create, Read or Retrive, Update, Delete

# %% [markdown]
# ### Properties of an Ideal Database
#
# 1. Integrity : Accuracy + Consistancy
# 2. Availability : Zero Downtime
# 3. Security : have to be secure
# 4. Independent of Application
# 5. Concurrency : Parallel uses

# %% [markdown]
# ### Different Types of Database

# %% [markdown]
# 1. `Relational Database`: Also Known as SQL database, these database use a relational model to organise data into table with row and column. (Oracle, MySQL, PostGre,SQL Server, Microsoft Access)
#
# 2. `NoSQL Database`: These database are designed to handle large amount of unstructured or semi-structured data, such as documents, images, or videos. (MongoDB)
#
# 3. `Column Database`: These database store data in  column rather than rows, making then well suited for data werehousing and analytical applications. (Amazon Redshift, Google BigQuery)
#
# 4. `Graph Database`: These databses are used to store graph and query-structured data, such as social network connections or recomendation section. (Neo4j, Amazon Neptune)
#
# 5. `Key-Value Database`: These databases store data as a collection of keys and values, making them well-suited for caching and simple data storage needs (Redis and Amazon DynamoDB).

# %% [markdown]
# ## Relational Database

# %% [markdown]
# Also Known as SQL Databases, these databases use relational model to organise data into tables with rows and columns.

# %% [markdown]
# `table` is also called as `relation`
#
# Similarly `Column` is called as `Attribute`
#
# `row` is called as `tuple`
#
# `number of records/rows/tuples` is called as `cardinality of the relation`
#
# `number of attributes/ columns/fields` is called as `Degree of the relation`
#
# `missing value, cell` known as `null`

# %% [markdown]
# ### What is DBMS?

# %% [markdown]
# A Database management system (DBMS) is a software that provides the interfaces and tools need to store, organize and manage data in database. A DBMS acts as an intermediary between the database and the applications or users that access the data stored in the database.

# %% [markdown]
# ### Functions of DBMS

# %% [markdown]
# `Data Management` : Store, Retrieve and Modify data
#
# `Integrity` : Maintain accuracy of Data
#
# `Concurrecny` : Simultaneous data access for multiple users
#
# `Transaction` : Modification to databse must either be successsfull or must not happen at all
#
# `Security` : Access to authorizes user only
#
# `Utilities` : Data import/export, user management, backup, logging

# %% [markdown]
# ### Database Keys

# %% [markdown]
#     A key in a database is an attribute or a set of attribute that uniquely identifies a tuple (row) in a table. Keys play a crucial role in ensuring tha integrity and reliability of a database by enforcing unique constraints on the data and establishing relationships between tables.

# %% [markdown]
# 1. `Super Key` - A super key is a combination of columns identifies any rows within a relational database management system table.
#
# 2. `Candidate Key` - A candidate key is a minimal super key, meaning it has no redundant attributes that van be used to uniquely identify a tuple (row) in the table.
#
# 3. `Primary Key` - A primary key is a unique identifier for each tuple in a table. There can only be one primary key in a table, and it cannot contain null values.
#
# 4. `Alternate key` - An alternate key us a candidate key that is not used as the primary key.
#
# 5. `Composite Key` - A composite key is a primary key that is made up of two or more attributes. Composite keys are used when a singe attribute is not sufficient to uniquely identify a tuple in a tuple.
#
# 6. `Surrogate Key` - Created when there is no data or column that can be a key. It's a separate and new column having a key to make the data unique.
#
# 7. `Foreign Key` - A foreign key is a primary key from one table that is used to establish a relationship with another table.

# %% [markdown]
# ### Cardinality of relationships

# %% [markdown]
#     Cardinality in a database relationship refers to the number of occurrences of an entity in a relationship with another entity. Cardinality defines the number of instances of one entity that can be associated with a single instances of the related entity

# %% [markdown]
# ### Drawbacks of Databases

# %% [markdown]
# 1. `Complexity`: Setting up and maintaining a database can be complex and time- consuming, especially for large and complex systems.
#
# 2. `Cost`: The cost of setting up and maintaining a database, including hardware, software, and personnel, can be high.
#
# 3. `Scalability`: As the amount of data stored in a database grows, it can become more difficult to manage, leading to performance and scalability issues.
#
# 4. `Data Integrity`: Ensuring the accuracy and consistency of data stored in a database can be a challenge, especially when multiple users are updating the data simultaneously.
#
# 5. `Security`: Securing a database from unauthorized access and protecting sensitive information can be difficult, especially with the increasing threat of cyber attacks.
#
# 5. `Data Migration`: Moving data from one database to another or upgrading to a new database can be a complex and time-consuming process.
#
# 6. `Flexibility`: The structure of a database is often rigid and inflexible, making it difficult to adapt to changing requirements or to accommodate new types of data.
